# %%
import os    
import pandas as pd 
import numpy as np
import tqdm

import matplotlib.pyplot as plt
import seaborn as sns               
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
data = pd.read_csv('../data/raw/crop-recommendation.csv')
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
#
#    soil_moisture  soil_type  ...  organic_matter  irrigation_frequency  \
# 0      29.446064          2  ...        3.121395                     4
# 1      12.851183          3  ...        2.142021                     4
# 2      29.363913          2  ...        1.474974                     1
# 3      26.207732          3  ...        8.393907                     1
# 4      28.236236          2  ...        5.202285                     3
#
#    crop_density  pest_pressure  fertilizer_usage  growth_stage  \
# 0     11.743910      57.607308        188.194958             1
# 1     16.797101      74.736879         70.963629             1
# 2     12.654395       1.034478        191.976077             1
# 3     10.864360      24.091888         55.761388             3
# 4     13.852910      38.811481        185.259702             2
#
#    urban_area_proximity  water_source_type  frost_risk  water_usage_efficiency
# 0              2.719614                  3   95.649985                1.193293
# 1              4.714427                  2   77.265694                1.752672
# 2             30.431736                  2   18.192168                3.035541
# 3             10.861071                  3   82.818720                1.273341
# 4             47.190777                  3   25.466499                2.578671
#
# [5 rows x 23 columns]

# %% [markdown]
# ## **EDA**

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   N                       2200 non-null   int64
#  1   P                       2200 non-null   int64
#  2   K                       2200 non-null   int64
#  3   temperature             2200 non-null   float64
#  4   humidity                2200 non-null   float64
#  5   ph                      2200 non-null   float64
#  6   rainfall                2200 non-null   float64
#  7   label                   2200 non-null   str
#  8   soil_moisture           2200 non-null   float64
#  9   soil_type               2200 non-null   int64
#  10  sunlight_exposure       2200 non-null   float64
#  11  wind_speed              2200 non-null   float64
#  12  co2_concentration       2200 non-null   float64
#  13  organic_matter          2200 non-null   float64
#  14  irrigation_frequency    2200 non-null   int64
#  15  crop_density            2200 non-null   float64
#  16  pest_pressure           2200 non-null   float64
#  17  fertilizer_usage        2200 non-null   float64
#  18  growth_stage            2200 non-null   int64
#  19  urban_area_proximity    2200 non-null   float64
#  20  water_source_type       2200 non-null   int64
#  21  frost_risk              2200 non-null   float64
#  22  water_usage_efficiency  2200 non-null   float64
# dtypes: float64(15), int64(7), str(1)
# memory usage: 410.8 KB

# %%
data.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall  soil_moisture    soil_type  \
# count  2200.000000  2200.000000    2200.000000  2200.000000
# mean      6.469480   103.463655      20.151388     1.991364
# std       0.773938    54.958389       5.793720     0.812263
# min       3.504752    20.211267      10.024260     1.000000
# 25%       5.971693    64.551686      15.179949     1.000000
# 50%       6.425045    94.867624      20.088481     2.000000
# 75%       6.923643   124.267508      25.255146     3.000000
# max       9.935091   298.560117      29.997860     3.000000
#
#        sunlight_exposure  ...  organic_matter  irrigation_frequency  \
# count        2200.000000  ...     2200.000000           2200.000000
# mean            8.570609  ...        5.465652              3.515000
# std             1.999382  ...        2.605294              1.697912
# min             5.000710  ...        1.003338              1.000000
# 25%             6.904620  ...        3.203903              2.000000
# 50%             8.609968  ...        5.418049              4.000000
# 75%            10.220394  ...        7.686417              5.000000
# max            11.991041  ...        9.999990              6.000000
#
#        crop_density  pest_pressure  fertilizer_usage  growth_stage  \
# count   2200.000000    2200.000000       2200.000000   2200.000000
# mean      12.344959      49.850701        125.846403      1.999545
# std        4.297494      28.886354         43.564527      0.818999
# min        5.004341       0.038103         50.209990      1.000000
# 25%        8.585734      24.379866         88.030737      1.000000
# 50%       12.303616      49.982421        126.441536      2.000000
# 75%       15.975567      74.681904        163.850536      3.000000
# max       19.988474      99.983849        199.982166      3.000000
#
#        urban_area_proximity  water_source_type   frost_risk  \
# count           2200.000000        2200.000000  2200.000000
# mean              24.801013           2.003636    50.304701
# std               14.523975           0.812021    28.580352
# min                0.017756           1.000000     0.054911
# 25%               12.212594           1.000000    26.104674
# 50%               24.922548           2.000000    50.171934
# 75%               37.322761           3.000000    75.262676
# max               49.992046           3.000000    99.957274
#
#        water_usage_efficiency
# count             2200.000000
# mean                 2.990268
# std                  1.139637
# min                  1.002106
# 25%                  2.051814
# 50%                  2.968675
# 75%                  3.968736
# max                  4.997130
#
# [8 rows x 22 columns]

# %%
numeric_columns = data.select_dtypes(include=[np.number]).columns
numeric_columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall',
#        'soil_moisture', 'soil_type', 'sunlight_exposure', 'wind_speed',
#        'co2_concentration', 'organic_matter', 'irrigation_frequency',
#        'crop_density', 'pest_pressure', 'fertilizer_usage', 'growth_stage',
#        'urban_area_proximity', 'water_source_type', 'frost_risk',
#        'water_usage_efficiency'],
#       dtype='str')

# %%
categoric_columns = data.select_dtypes(include=['object']).columns
categoric_columns
# Out:
# /var/folders/7w/4g_mcwx906bdn7v4ss6q9ydw0000gn/T/ipykernel_7164/2837077031.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categoric_columns = data.select_dtypes(include=['object']).columns
# Index(['label'], dtype='str')

# %%
data['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))

sns.heatmap(
    data.isnull(),
    cmap='viridis',
    cbar=False,
    yticklabels=False,
)

plt.title('Missing Value Hetamap', fontsize=14, pad=20)
plt.tight_layout
plt.show()

print("\nJumlah Missing Value per Kolom:")
print(data.isnull().sum())
# Out:
# Jumlah Missing Value per Kolom:
# N                         0
# P                         0
# K                         0
# temperature               0
# humidity                  0
# ph                        0
# rainfall                  0
# label                     0
# soil_moisture             0
# soil_type                 0
# sunlight_exposure         0
# wind_speed                0
# co2_concentration         0
# organic_matter            0
# irrigation_frequency      0
# crop_density              0
# pest_pressure             0
# fertilizer_usage          0
# growth_stage              0
# urban_area_proximity      0
# water_source_type         0
# frost_risk                0
# water_usage_efficiency    0
# dtype: int64

# %%
fig, axes = plt.subplots(nrows=6, ncols=5, figsize=(20, 16))
axes = axes.flatten() 

for i, col in enumerate(numeric_columns):
    sns.histplot(data[col], kde=True, ax=axes[i], color='blue', edgecolor=None, bins=25)
    axes[i].set_title(f'Distribusi: {col}', fontsize=12, fontweight='bold')
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Frekuensi')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(20, 24))
axes = axes.flatten()

for i, col in enumerate(numeric_columns):
    sns.boxplot(y=data[col], ax=axes[i], color='mediumslateblue')
    axes[i].set_title(f'Boxplot: {col}', fontsize=12, fontweight='bold')
    axes[i].set_ylabel('Value')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
plt.tight_layout()
plt.show()

# %%
correlation = data[numeric_columns].corr()

mask = np.triu(np.ones_like(correlation, dtype=bool,), k=1)

plt.figure(figsize=(16, 12))
sns.heatmap(correlation, 
            mask=mask,               
            annot=True,             
            fmt=".2f",               
            cmap='coolwarm',         
            vmax=1, vmin=-1,         
            center=0,                
            square=True,             
            linewidths=.5,           
            cbar_kws={"shrink": .5})


plt.title('Matriks Korelasi Segitiga Bawah', fontsize=14, fontweight='bold', pad=20)
plt.xticks(rotation=40, ha='right', fontsize=10)
plt.yticks(fontsize=10)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.countplot(data=data, x='label', color='mediumslateblue', ax=axes[0])
axes[0].set_title("Frequency of Each Label", fontsize=14, pad=10)
axes[0].tick_params(axis='x', rotation=90)

sns.heatmap(data.isnull(), cmap='viridis', ax=axes[1], cbar=False, yticklabels=False)
axes[1].set_title("Missing Value Heatmap", fontsize=14, pad=10)
axes[1].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.boxplot(data=data, x='label', y='rainfall', palette='viridis')
plt.title("Distribusi Hujan per Jenis Tanaman", fontsize=16, pad=10)
plt.tick_params(axis='x', rotation=70)
plt.tight_layout
plt.show()
# Out:
# /var/folders/7w/4g_mcwx906bdn7v4ss6q9ydw0000gn/T/ipykernel_7164/2068063628.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='label', y='rainfall', palette='viridis')

# %%
fitur_dasar = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'soil_moisture', 'sunlight_exposure']

fig, axes = plt.subplots(3,3, figsize=(30, 25))
axes = axes.flatten()

for i, columns in enumerate(fitur_dasar):
    sns.boxplot(data=data, x='label', y=columns, ax=axes[i], palette='viridis')
    axes[i].set_title(f'Distribusi: {columns} per Jenis Tanaman', fontsize=16, fontweight='bold')
    axes[i].set_xlabel('') 
    axes[i].set_ylabel(col)

    axes[i].tick_params(axis='x', rotation=70)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/7w/4g_mcwx906bdn7v4ss6q9ydw0000gn/T/ipykernel_7164/2252957167.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='label', y=columns, ax=axes[i], palette='viridis')
# /var/folders/7w/4g_mcwx906bdn7v4ss6q9ydw0000gn/T/ipykernel_7164/2252957167.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='label', y=columns, ax=axes[i], palette='viridis')
# /var/folders/7w/4g_mcwx906bdn7v4ss6q9ydw0000gn/T/ipykernel_7164/2252957167.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='label', y=columns, ax=axes[i], palette='viridis')
# /var/folders/7w/4g_mcwx906bdn7v4ss6q9ydw0000gn/T/ipykernel_7164/2252957167.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='label', y=columns, ax=axes[i], palette='viridis')
# /var/folders/7w/4g_mcwx906bdn7v4ss6q9ydw0000gn/T/ipykernel_7164/2252957167.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='label', y=columns, ax=axes[i], palette='viridis')
# /var/folders/7w/4g_mcwx906bdn7v4ss6q9ydw0000gn/T/ipykernel_7164/2252957167.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='label', y=columns, ax=axes[i], palette='viridis')
# /var/folders/7w/4g_mcwx906bdn7v4ss6q9ydw0000gn/T/ipykernel_7164/2252957167.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='label', y=columns, ax=axes[i], palette='viridis')
# /var/folders/7w/4g_mcwx906bdn7v4ss6q9ydw0000gn/T/ipykernel_7164/2252957167.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='label', y=columns, ax=axes[i], palette='viridis')
# /var/folders/7w/4g_mcwx906bdn7v4ss6q9ydw0000gn/T/ipykernel_7164/2252957167.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='label', y=columns, ax=axes[i], palette='viridis')

# %%
plt.figure(figsize=(16, 10))
graph = sns.pairplot(data=data, vars=fitur_dasar, hue='label', palette='husl', plot_kws={'alpha':0.6, 's':20})
graph.fig.suptitle("Analisis Separabilitas antara Fitur Dasar Agronomi vs Label Tanaman", fontsize=20, y= 1.02, fontweight='bold')
plt.tight_layout
plt.show()

# %%
fig, axes = plt.subplots(3, 3, figsize=(16, 12))
axes = axes.flatten()

for i, col in enumerate(fitur_dasar):
    sns.regplot(data=data, x=columns, y='water_usage_efficiency', color='orange',
                ax=axes[i], scatter_kws={'alpha':0.3}, line_kws={'color':'red', 'linewidth':2})
    axes[i].set_title(f'Linearity Check: {columns} vs Water Efficiency', fontweight='bold')

plt.tight_layout()
plt.show()
